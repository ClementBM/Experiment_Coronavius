# %% [markdown]
# # Import Data

# %%
import os

# !git clone https://github.com/CSSEGISandData/COVID-19.git
MAIN_FOLDER = "/content/COVID-19/csse_covid_19_data/csse_covid_19_time_series/"

CONFIRMED_PATH = os.path.join(MAIN_FOLDER, "time_series_19-covid-Confirmed.csv")
DEATHS_PATH = os.path.join(MAIN_FOLDER, "time_series_19-covid-Deaths.csv")
RECOVERED_PATH = os.path.join(MAIN_FOLDER, "time_series_19-covid-Recovered.csv")
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 10703 (delta 59), reused 103 (delta 32), pack-reused 10572
# Receiving objects: 100% (10703/10703), 39.92 MiB | 43.12 MiB/s, done.
# Resolving deltas: 100% (5124/5124), done.

# %%
import pandas as pd
df_confirmed = pd.read_csv(CONFIRMED_PATH)
df_deaths = pd.read_csv(DEATHS_PATH)
df_recovered = pd.read_csv(RECOVERED_PATH)

# %% [markdown]
# # EDA

# %%
display(df_confirmed.head())
display(df_confirmed.T.head())
display(df_confirmed.shape)
display(df_confirmed.columns)
display(df_confirmed.iloc[:10,:10].dtypes)
display(df_confirmed.describe(percentiles=[0.25,0.5,0.75,0.85,0.95,0.99]).T)
# Out:
#   Province/State  Country/Region      Lat  ...  3/7/20  3/8/20  3/9/20
# 0          Anhui  Mainland China  31.8257  ...     990     990     990
# 1        Beijing  Mainland China  40.1824  ...     426     428     428
# 2      Chongqing  Mainland China  30.0572  ...     576     576     576
# 3         Fujian  Mainland China  26.0789  ...     296     296     296
# 4          Gansu  Mainland China  36.0611  ...     120     124     124
#
# [5 rows x 52 columns]
#                              0  ...                     265
# Province/State           Anhui  ...  Spartanburg County, SC
# Country/Region  Mainland China  ...                      US
# Lat                    31.8257  ...                 34.8606
# Long                   117.226  ...                -81.9535
# 1/22/20                      1  ...                       0
#
# [5 rows x 266 columns]
# (266, 52)
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20'],
#       dtype='object')
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
# 1/23/20             int64
# 1/24/20             int64
# 1/25/20             int64
# 1/26/20             int64
# 1/27/20             int64
# dtype: object
#          count        mean          std  ...         95%         99%         max
# Lat      266.0   32.659257    18.912704  ...   53.091775    62.28019     64.9631
# Long     266.0  -14.852509    88.490219  ...  125.296350   147.80421    174.8860
# 1/22/20  266.0    2.086466    27.279200  ...    2.000000    11.40000    444.0000
# 1/23/20  266.0    2.454887    27.377994  ...    5.000000    23.75000    444.0000
# 1/24/20  266.0    3.537594    34.082925  ...    9.000000    38.45000    549.0000
# 1/25/20  266.0    5.390977    47.434855  ...   18.000000    58.75000    761.0000
# 1/26/20  266.0    7.962406    66.288609  ...   34.500000    90.35000   1058.0000
# 1/27/20  266.0   11.003759    89.313334  ...   46.750000   128.00000   1423.0000
# 1/28/20  266.0   20.969925   219.187572  ...   62.250000   169.75000   3554.0000
# 1/29/20  266.0   23.180451   220.524806  ...   77.500000   240.60000   3554.0000
# 3/6/20   266.0  382.703008  4179.700434  ...  647.500000  4674.85000  67592.0000
# 3/7/20   266.0  397.875940  4196.988333  ...  679.750000  5844.00000  67666.0000
# 3/8/20   266.0  412.834586  4213.348081  ...  690.250000  6827.80000  67707.0000
# 3/9/20   266.0  427.003759  4232.741169  ...  742.500000  7271.95000  67743.0000
#
# [50 rows x 11 columns]

# %% [markdown]
# # Cleaning Data

# %%
df_confirmed = df_confirmed.drop(columns=['Lat', 'Long'])
df_confirmed["Province/State"] = df_confirmed["Province/State"].fillna(df_confirmed["Country/Region"])

display(df_confirmed.tail())
# Out:
#              Province/State Country/Region  1/22/20  ...  3/7/20  3/8/20  3/9/20
# 261       Collin County, TX             US        0  ...       0       0       1
# 262    Jefferson County, KY             US        0  ...       0       0       1
# 263    Jefferson Parish, LA             US        0  ...       0       0       1
# 264       Shasta County, CA             US        0  ...       0       0       1
# 265  Spartanburg County, SC             US        0  ...       0       0       1
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Count by Country

# %%
df_bycountry = df_confirmed.groupby('Country/Region').sum()
df_bycountry.loc["Total"] = df_bycountry.sum(axis=0)
display(df_bycountry)
# Out:
#                       1/22/20  1/23/20  1/24/20  ...  3/7/20  3/8/20  3/9/20
# Country/Region                                   ...
# Afghanistan                 0        0        0  ...       1       4       4
# Albania                     0        0        0  ...       0       0       2
# Algeria                     0        0        0  ...      17      19      20
# Andorra                     0        0        0  ...       1       1       1
# Argentina                   0        0        0  ...       8      12      12
# ...                       ...      ...      ...  ...     ...     ...     ...
# Ukraine                     0        0        0  ...       1       1       1
# United Arab Emirates        0        0        0  ...      45      45      45
# Vatican City                0        0        0  ...       1       1       1
# Vietnam                     0        2        2  ...      18      30      30
# Total                     555      653      941  ...  105835  109814  113583
#
# [112 rows x 48 columns]

# %% [markdown]
# ## Normalize

# %%
maximums = df_bycountry.iloc[:, -1]
df_bycountry_norm = df_bycountry.div(maximums.to_numpy(), axis=0)
display(df_bycountry_norm)
# Out:
#                        1/22/20   1/23/20   1/24/20  ...    3/7/20    3/8/20  3/9/20
# Country/Region                                      ...
# Afghanistan           0.000000  0.000000  0.000000  ...  0.250000  1.000000     1.0
# Albania               0.000000  0.000000  0.000000  ...  0.000000  0.000000     1.0
# Algeria               0.000000  0.000000  0.000000  ...  0.850000  0.950000     1.0
# Andorra               0.000000  0.000000  0.000000  ...  1.000000  1.000000     1.0
# Argentina             0.000000  0.000000  0.000000  ...  0.666667  1.000000     1.0
# ...                        ...       ...       ...  ...       ...       ...     ...
# Ukraine               0.000000  0.000000  0.000000  ...  1.000000  1.000000     1.0
# United Arab Emirates  0.000000  0.000000  0.000000  ...  1.000000  1.000000     1.0
# Vatican City          0.000000  0.000000  0.000000  ...  1.000000  1.000000     1.0
# Vietnam               0.000000  0.066667  0.066667  ...  0.600000  1.000000     1.0
# Total                 0.004886  0.005749  0.008285  ...  0.931786  0.966817     1.0
#
# [112 rows x 48 columns]

# %% [markdown]
# ## Plot countries

# %%
import matplotlib.pyplot as plt

def plot_by_country(df, countries):
  plt.subplots(figsize = (14,10))
  lines = plt.plot(df.loc[countries,:].T)
  plt.legend(iter(lines), countries)
  plt.xticks(rotation=90)
  plt.show()

# %% [markdown]
# ## Plot China, Italy, France, South Korea, Japan, US

# %%
plot_by_country(df_bycountry, ["Mainland China", "France", "Italy", "South Korea", "Japan", "US"])

# %% [markdown]
# ## Plot normed China, Italy, France, South Korea, Japan, US

# %%
plot_by_country(df_bycountry_norm, ["Mainland China", "France", "Italy", "South Korea", "Japan", "US"])

# %% [markdown]
# ## Confirmed cases in Hubei province from 22th of january to 22th of february

# %%
df_byprovince = df_confirmed.groupby("Province/State").sum()
plt.subplots(figsize = (14,10))
lines = plt.plot(df_byprovince.loc["Hubei",:"2/22/20"].T)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Correlation

# %%
import numpy as np

# https://towardsdatascience.com/four-ways-to-quantify-synchrony-between-time-series-data-b99136c4a9c9
def crosscorr(datax, datay, lag=0):
    """ Lag-N cross correlation. 
    :lag: default 0, (int)
    :datax: (pandas.Series)
    :datay: (pandas.Series)
    :Returns: crosscorr (float)
    """
    return datax.corr(datay.shift(lag))

# %%
def synchrony(df_1, df_2, absolute_lag):
  x_range = np.arange(-absolute_lag, absolute_lag + 1)

  rs = [crosscorr(df_1, df_2, lag) for lag in x_range]

  offset = int(len(rs)/2) - np.argmax(rs)

  f,ax=plt.subplots(figsize=(14,3))
  ax.plot(rs)
  ax.axvline(int(len(rs)/2),color='k',linestyle='--',label='Center')
  ax.axvline(np.argmax(rs),color='r',linestyle='--',label='Peak synchrony')
  ax.set(title=f'Offset = {offset} frames', xlabel='Offset',ylabel='Pearson r')
  ax.set_xticks(x_range + absolute_lag)
  ax.set_xticklabels(x_range);
  plt.legend()
  plt.xticks(rotation=90)
  plt.show()

# %%
def plot_with_lag(df, country_1, country_2, lag):
  plt.subplots(figsize = (14,10))

  s_1 = df.loc[country_1,:].to_numpy()
  if lag > 0:
    plt.plot(s_1, label=country_1, color='red')
  else:
    plt.plot(np.insert(s_1, 0, np.zeros(abs(lag))), label=country_1, color='red')

  s_2 = df.loc[country_2,:].to_numpy()
  if lag > 0:
    plt.plot(s_2, label=country_2, color='blue')
  else:
    plt.plot(np.insert(s_2, 0, np.zeros(abs(lag))), label=country_2, color='blue')
  
  if lag > 0:
    plt.plot(np.insert(s_2, 0, np.zeros(abs(lag))), label=country_2 + " lagged", color='blue', linestyle="--")
  else:
    plt.plot(s_2, label=country_2 + " lagged", color='blue', linestyle="--")
  
  plt.legend(loc="upper left")
  plt.xticks(rotation=0)
  plt.xlabel("Days")
  plt.ylabel("Confirmed")
  plt.show()

# %% [markdown]
# ## Italy leads France by about 6 days

# %%
synchrony(df_bycountry.loc["Italy",:], df_bycountry.loc["France",:], 14)

# %%
plot_with_lag(df_bycountry, "Italy", "France", -6)

# %% [markdown]
# ## China leads Italy by about 34 days

# %%
synchrony(df_bycountry_norm.loc["Mainland China",:], df_bycountry_norm.loc["Italy",:], 36)

# %%
plot_with_lag(df_bycountry, "Mainland China", "Italy", -34)
